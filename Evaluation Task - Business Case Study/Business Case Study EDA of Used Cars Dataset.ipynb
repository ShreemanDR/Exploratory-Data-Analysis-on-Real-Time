# %% [markdown]
# # <u>__Business Case Study: EDA of Used Cars Dataset__

# %% [markdown]
# ## __Importing Data and Required Packages__

# %%
import pandas as pd
df=pd.read_csv("C:/Users/Admin/Documents/used_cars_data.csv")
df # inspecting the dataframe
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %% [markdown]
# ### __Data Checks to Perform before Data Cleaning (Data Exploration)__
# ##### ➽ Check for Duplicate Value
# ##### ➽ Check for Check for Missing Values
# ##### ➽ Check for DataType
# ##### ➽ Check the number of Unique Value in every Columns
# ##### ➽ Check Statistics of Dataset

# %%
df.info() # getting some basic information on the different fields
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   object
#  10  Power              7207 non-null   object
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %%
# Check for duplicate rows
duplicates = df.duplicated().sum()
print("Number of duplicate rows:", duplicates)
# Out:
# Number of duplicate rows: 0

# %%
# Checking how many rows and columns there are
Rows_and_columns = df.shape
print("Number of Rows and Columns :",Rows_and_columns)
# Out:
# Number of Rows and Columns : (7253, 14)

# %%
# Check for missing values
missing_values = df.isna().sum()
print("Missing Values:")
print(missing_values)
# Out:
# Missing Values:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %%
# Checking the percentage
Total_No_of_Null_Values_in_New_Price = df["New_Price"].isnull().sum()
Total_No_of_Values_in_New_Price = 7253
Total_No_of_Null_Values_in_Price = df["Price"].isnull().sum()
Total_No_of_Values_in_Price = 7253
print("Total No. of Null Values in New_Price  :",Total_No_of_Null_Values_in_New_Price)
print("Total NO. OF Values in New_Price :",Total_No_of_Values_in_New_Price)
print("Total No. of Null Values in Price  :",Total_No_of_Null_Values_in_Price)
print("Total NO. OF Values in Price :",Total_No_of_Values_in_Price)
print("-"*100)

print("% TO CHECK WHETHER Missing Value is lesser than 20% of the Dataset IN New_Price :")
print((Total_No_of_Null_Values_in_New_Price/Total_No_of_Values_in_New_Price)*100)
print("% TO CHECK WHETHER Missing Value is lesser than 20% of the Dataset IN Price :")
print((Total_No_of_Null_Values_in_Price/Total_No_of_Values_in_Price)*100)
# Out:
# Total No. of Null Values in New_Price  : 6247
# Total NO. OF Values in New_Price : 7253
# Total No. of Null Values in Price  : 1234
# Total NO. OF Values in Price : 7253
# ----------------------------------------------------------------------------------------------------
# % TO CHECK WHETHER Missing Value is lesser than 20% of the Dataset IN New_Price :
# 86.12987729215497
# % TO CHECK WHETHER Missing Value is lesser than 20% of the Dataset IN Price :
# 17.01364952433476

# %%
# Removing the New_Price Column
df.drop('New_Price', axis=1, inplace=True)

# %%
df.head() # inspecting the head of the dataframe whether it is removed
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  Price
# 0  58.16 bhp    5.0   1.75
# 1  126.2 bhp    5.0  12.50
# 2   88.7 bhp    5.0   4.50
# ...

# %% [markdown]
# ## __Data Cleaning__

# %% [markdown]
# ## >> __Task 1 - Replacing the Missing Values (seperately)__

# %%
df.isnull().sum() # Checking how many misiing values are there in every column
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# Price                1234
# dtype: int64

# %% [markdown]
# ##### __Mileage__

# %%
df_mode = df.Mileage.mode()[0]
print("Mileage mode =",df_mode)
df.Mileage.fillna(df_mode,inplace=True)
df.isnull().sum()
# Out:
# Mileage mode = 17.0 kmpl
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                 46
# Power                  46
# Seats                  53
# Price                1234
# dtype: int64

# %% [markdown]
# ##### __Engine__

# %%
df_mode2 = df.Engine.mode()[0]
print("Mode of Engine =",df_mode2)
df.Engine.fillna(df_mode2,inplace=True)
df.isnull().sum()
# Out:
# Mode of Engine = 1197 CC
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                  0
# Power                  46
# Seats                  53
# Price                1234
# dtype: int64

# %% [markdown]
# ##### __Power__

# %%
df_mode3 = df.Power.mode()[0]
print("Mode of Power =",df_mode3)
df.Power.fillna(df_mode3,inplace=True)
df.isnull().sum()
# Out:
# Mode of Power = 74 bhp
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                  0
# Power                   0
# Seats                  53
# Price                1234
# dtype: int64

# %% [markdown]
# ##### __Seats__

# %%
print("Median of Seats :",df.Seats.median())
df.Seats.fillna(df.Seats.median(),inplace=True)
df.isnull().sum()
# Out:
# Median of Seats : 5.0
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                  0
# Power                   0
# Seats                   0
# Price                1234
# dtype: int64

# %% [markdown]
# ##### __Price__

# %%
print("Median of Price :",df.Price.median())
df.Price.fillna(df.Price.median(),inplace=True)
df.isnull().sum()
# Out:
# Median of Price : 5.64
# S.No.                0
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
df.head() #checking
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  Price
# 0  58.16 bhp    5.0   1.75
# 1  126.2 bhp    5.0  12.50
# 2   88.7 bhp    5.0   4.50
# ...

# %%
summary = df['Price'].describe()
print(summary)
# Out:
# count    7253.000000
# mean        8.826235
# std        10.293313
# min         0.440000
# 25%         3.850000
# 50%         5.640000
# 75%         8.400000
# max       160.000000
# Name: Price, dtype: float64

# %% [markdown]
# __Outliers Detection and Removal__

# %%
# Outlier Detection
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x=df["Price"])
# Out:
# <Axes: xlabel='Price'>

# %%
def remove_outliers_iqr(df, feature):
    Q1=df[feature].quantile(0.25)
    Q3=df[feature].quantile(0.75)
    IQR=Q3-Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df [(df [feature] >= lower_bound) & (df[feature] <= upper_bound)]

A = remove_outliers_iqr(df,'Price')
print("Before Cleaning", df.shape)
print("After Cleaning", A.shape)
# Out:
# Before Cleaning (7253, 13)
# After Cleaning (6271, 13)

# %%
summary = df['Price'].describe()
print(summary)
# Out:
# count    7253.000000
# mean        8.826235
# std        10.293313
# min         0.440000
# 25%         3.850000
# 50%         5.640000
# 75%         8.400000
# max       160.000000
# Name: Price, dtype: float64

# %% [markdown]
# ## >> __Task 2 - Price Distributions of CAR__

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={"figure.figsize":(7,5)})
sns.distplot(df.Price,bins=30)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18984\690626188.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Price,bins=30)
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# __Converting the Columns Mileage, Engine, Power to numerical values in DF__

# %%
df_copy = df.copy() # TO ENSURE THE DATA ORIGINALITY

# %%
# Converting the Columns Mileage,Engine,Power to numerical values
import re
# Function to extract numeric values
def extract_numeric_value(text):
    numeric_value = re.findall(r"[-+]?\d*\.\d+|\d+", text)
    return float(numeric_value[0]) if numeric_value else None

# Apply the function to the DataFrame column
df_copy['Mileage_in_kmpl'] = df_copy['Mileage'].apply(extract_numeric_value)
df_copy['Engine_in_CC'] = df_copy['Engine'].apply(extract_numeric_value)
df_copy['Power_in_bhp'] = df_copy['Power'].apply(extract_numeric_value)
df_copy.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  Price  Mileage_in_kmpl  Engine_in_CC  Power_in_bhp
# ...

# %%
columns_to_remove = ['Mileage', 'Engine', 'Power']
df_copy = df_copy.drop(columns=columns_to_remove)

# %%
df_copy.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Seats  Price  \
# 0              72000       CNG       Manual      First    5.0   1.75
# 1              41000    Diesel       Manual      First    5.0  12.50
# 2              46000    Petrol       Manual      First    5.0   4.50
# 3              87000    Diesel       Manual      First    7.0   6.00
# 4              40670    Diesel    Automatic     Second    5.0  17.74
#
#    Mileage_in_kmpl  Engine_in_CC  Power_in_bhp
# 0            26.60         998.0         58.16
# 1            19.67        1582.0        126.20
# ...

# %% [markdown]
# ## >> __Task 3 - Correlate Price with Year, Kilometer_Driven, Milage__

# %% [markdown]
# ### __Correlation (Numerical to Numerical)__

# %%
df_corr = df_copy[["Price","Year","Kilometers_Driven","Mileage_in_kmpl","Engine_in_CC","Power_in_bhp"]]
df_corr.head()
# Out:
#    Price  Year  Kilometers_Driven  Mileage_in_kmpl  Engine_in_CC  Power_in_bhp
# 0   1.75  2010              72000            26.60         998.0         58.16
# 1  12.50  2015              41000            19.67        1582.0        126.20
# 2   4.50  2011              46000            18.20        1199.0         88.70
# 3   6.00  2012              87000            20.77        1248.0         88.76
# 4  17.74  2013              40670            15.20        1968.0        140.80

# %%
corr = df_corr.corr()
corr
# Out:
#                       Price      Year  Kilometers_Driven  Mileage_in_kmpl  \
# Price              1.000000  0.276009          -0.011062        -0.278215
# Year               0.276009  1.000000          -0.187859         0.322431
# Kilometers_Driven -0.011062 -0.187859           1.000000        -0.069111
# Mileage_in_kmpl   -0.278215  0.322431          -0.069111         1.000000
# Engine_in_CC       0.601381 -0.049098           0.094071        -0.578373
# Power_in_bhp       0.703077  0.018841           0.029508        -0.516335
#
#                    Engine_in_CC  Power_in_bhp
# Price                  0.601381      0.703077
# Year                  -0.049098      0.018841
# Kilometers_Driven      0.094071      0.029508
# Mileage_in_kmpl       -0.578373     -0.516335
# Engine_in_CC           1.000000      0.860235
# Power_in_bhp           0.860235      1.000000

# %%
corr = df_corr.corr()
plt.figure(figsize=(6,6))
sns.heatmap(corr, annot=True, cmap="Blues")
# Out:
# <Axes: >

# %%
sns.pairplot(df_corr)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
correlation = df_corr[['Price', 'Year', 'Kilometers_Driven', 'Mileage_in_kmpl',"Engine_in_CC","Power_in_bhp"]].corr()
print(correlation)
# Out:
#                       Price      Year  Kilometers_Driven  Mileage_in_kmpl  \
# Price              1.000000  0.276009          -0.011062        -0.278215
# Year               0.276009  1.000000          -0.187859         0.322431
# Kilometers_Driven -0.011062 -0.187859           1.000000        -0.069111
# Mileage_in_kmpl   -0.278215  0.322431          -0.069111         1.000000
# Engine_in_CC       0.601381 -0.049098           0.094071        -0.578373
# Power_in_bhp       0.703077  0.018841           0.029508        -0.516335
#
#                    Engine_in_CC  Power_in_bhp
# Price                  0.601381      0.703077
# Year                  -0.049098      0.018841
# Kilometers_Driven      0.094071      0.029508
# Mileage_in_kmpl       -0.578373     -0.516335
# Engine_in_CC           1.000000      0.860235
# Power_in_bhp           0.860235      1.000000

# %% [markdown]
# #### __Without Engine and Power :__
# - From the Given Data the __Mileage_in_kmpl & Year__ is negatively low Correlated.
# - From the Given Data the __Year & Mileage_in_kmpl__ and __Price & Year__ is POSITIVELY Correlated.
# - but even though it is positive it still very low positive Correlation.

# %% [markdown]
# #### __With Engine and Power :__
# - __Engine_in_CC & Power_in_bhp__ is HIGHLY Correlated as 0.860235.
# - __Mileage_in_kmpl with Mileage_in_kmpl__ is negatively correlated.
# - __Price with Engine_in_CC & Power_in_bhp__ is positively correlated.

# %% [markdown]
# ## __>> Task 4 - FEATURE IMPORTANCE__

# %%
df_copy.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Seats  Price  \
# 0              72000       CNG       Manual      First    5.0   1.75
# 1              41000    Diesel       Manual      First    5.0  12.50
# 2              46000    Petrol       Manual      First    5.0   4.50
# 3              87000    Diesel       Manual      First    7.0   6.00
# 4              40670    Diesel    Automatic     Second    5.0  17.74
#
#    Mileage_in_kmpl  Engine_in_CC  Power_in_bhp
# 0            26.60         998.0         58.16
# 1            19.67        1582.0        126.20
# ...

# %%
df_copy.isnull().sum()
# Out:
# S.No.                  0
# Name                   0
# Location               0
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Seats                  0
# Price                  0
# Mileage_in_kmpl        0
# Engine_in_CC           0
# Power_in_bhp         129
# dtype: int64

# %%
print("Median of Power_in_bhp :",df_copy.Power_in_bhp.median())
df_copy.Power_in_bhp.fillna(df_copy.Power_in_bhp.median(),inplace=True)
df_copy.isnull().sum()
# Out:
# Median of Power_in_bhp : 93.7
# S.No.                0
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Seats                0
# Price                0
# Mileage_in_kmpl      0
# Engine_in_CC         0
# Power_in_bhp         0
# dtype: int64

# %% [markdown]
# ### __Feature Importance Using SelectKBest and fclassif__

# %% [markdown]
# #### __Numerical Features with Price__

# %% [markdown]
# #### 1) Manually

# %%
# Numerical Features
from sklearn.feature_selection import SelectKBest, f_classif
x = df_copy[['Year','Kilometers_Driven','Seats','Mileage_in_kmpl','Engine_in_CC','Power_in_bhp']] # Numerical Features
y = df_copy['Price']

f_p_values=f_classif(x,y)
f_p_values
# Out:
# (array([3.71156522, 1.83579229, 1.66224593, 1.80692177, 5.58529066,
#         7.95313622]),
#  array([3.94362862e-264, 1.50140470e-052, 9.28786453e-037, 8.15693763e-050,
#         0.00000000e+000, 0.00000000e+000]))

# %%
f_p_values=pd.Series(f_p_values[1])
f_p_values.index=x.columns
f_p_values
# Out:
# Year                 3.943629e-264
# Kilometers_Driven     1.501405e-52
# Seats                 9.287865e-37
# Mileage_in_kmpl       8.156938e-50
# Engine_in_CC          0.000000e+00
# Power_in_bhp          0.000000e+00
# dtype: float64

# %% [markdown]
# - As you can see the closest to 0 is for __Price__ is __Engine_in_CC and Power_in_bhp__. Which means these two have a highly signifiacnt relationship with __Price__.
# - After that Year is also significant relationship with __Price__.

# %% [markdown]
# #### 2) Auto

# %%
best_features = SelectKBest(score_func=f_classif, k=2)
fit = best_features.fit(x,y)
selected_features = x.columns[fit.get_support()]

# %%
selected_features
# Out:
# Index(['Engine_in_CC', 'Power_in_bhp'], dtype='object')

# %% [markdown]
# - Same results as from Manual. __Price__ with __Engine_in_CC and Power_in_bhp__

# %% [markdown]
# #### __Categorical Features with Price__

# %% [markdown]
# #### 1) Manually

# %%
x1 = df_copy[["Location","Fuel_Type","Transmission","Owner_Type"]] # categorical
x1
# Out:
#         Location Fuel_Type Transmission Owner_Type
# 0         Mumbai       CNG       Manual      First
# 1           Pune    Diesel       Manual      First
# 2        Chennai    Petrol       Manual      First
# 3        Chennai    Diesel       Manual      First
# 4     Coimbatore    Diesel    Automatic     Second
# ...          ...       ...          ...        ...
# 7248   Hyderabad    Diesel       Manual      First
# 7249      Mumbai    Petrol    Automatic      First
# 7250     Kolkata    Diesel       Manual      First
# 7251        Pune    Petrol    Automatic      Third
# 7252       Kochi    Diesel    Automatic      First
#
# [7253 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
x1["Location"]=label.fit_transform(x1["Location"])
x1["Fuel_Type"]=label.fit_transform(x1["Fuel_Type"])
x1["Transmission"]=label.fit_transform(x1["Transmission"])
x1["Owner_Type"]=label.fit_transform(x1["Owner_Type"])
x1.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18984\3020381781.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x1["Location"]=label.fit_transform(x1["Location"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18984\3020381781.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x1["Fuel_Type"]=label.fit_transform(x1["Fuel_Type"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18984\3020381781.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
cf_p_values=f_classif(x1,y)

# %%
cf_p_values
# Out:
# (array([0.8325279, 1.8246425, 4.1996126, 1.0729531], dtype=float32),
#  array([0.9999884 , 0.        , 0.        , 0.04634142], dtype=float32))

# %%
cf_p_values=pd.Series(cf_p_values[1])
cf_p_values.index=x1.columns
cf_p_values
# Out:
# Location        0.999988
# Fuel_Type       0.000000
# Transmission    0.000000
# Owner_Type      0.046341
# dtype: float32

# %%
best_features = SelectKBest(score_func=f_classif, k=2)
fit = best_features.fit(x1,y)
selected_features = x1.columns[fit.get_support()]

# %%
selected_features
# Out:
# Index(['Fuel_Type', 'Transmission'], dtype='object')

# %% [markdown]
# - __Fuel_Type & Transmission__ is highly significant relationship with __Price__.

# %% [markdown]
# #### 1) Auto

# %%
# Categorical Features
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Identify categorical features
categorical_features = df_copy.select_dtypes(include=['object']).columns

anova_results = {}
for feature in categorical_features:
    model = ols(f'Price ~ C({feature})', data=df_copy).fit()
    anova_table = sm.stats.anova_lm(model, typ=2)
    anova_results[feature] = anova_table['PR(>F)'][0]

# Sort features by p-value
sorted_anova_results = sorted(anova_results.items(), key=lambda x: x[1])

# Display the sorted ANOVA results
print("ANOVA Results (sorted by p-value):")
for feature, p_value in sorted_anova_results:
    print(f"Feature: {feature}, p-value: {p_value}")
# Out:
# ANOVA Results (sorted by p-value):
# Feature: Name, p-value: 0.0
# Feature: Transmission, p-value: 0.0
# Feature: Fuel_Type, p-value: 1.7895904293641985e-137
# Feature: Location, p-value: 9.811845717489843e-75
# Feature: Owner_Type, p-value: 6.202491273859318e-12
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18984\2497650863.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   anova_results[feature] = anova_table['PR(>F)'][0]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18984\2497650863.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   anova_results[feature] = anova_table['PR(>F)'][0]
# ...

# %% [markdown]
# ## __>>Task 5 - StoryTelling__

# %% [markdown]
# - Presenting the findings with a good story
